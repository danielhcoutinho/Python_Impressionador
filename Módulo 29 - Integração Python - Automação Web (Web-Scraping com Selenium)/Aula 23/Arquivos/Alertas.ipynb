# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\alertas.html"
navegador.get(arquivo)

# %% [markdown]
# #### Alertas Básicos

# %%
# selecionar um alerta
navegador.find_element(By.XPATH, '/html/body/div[1]/input').click()

# %%
# forma simples
# alerta = navegador.switch_to.alert
# alerta.accept()

# forma "completa"
from selenium.webdriver.common.alert import Alert

alerta = Alert(navegador)
alerta.accept()

# %% [markdown]
# #### Alertas de Confirmação

# %%
navegador.find_element(By.XPATH, '/html/body/div[2]/input').click()

alerta = Alert(navegador)

# aceitar
alerta.accept()

# cancelar
#alerta.dismiss()

# %% [markdown]
# #### Pegar o texto do alerta

# %%
navegador.find_element(By.XPATH, '/html/body/div[2]/input').click()

alerta = Alert(navegador)
texto = alerta.text
print(texto)
# Out:
# Quer confirmar a emissão da NF?

# %% [markdown]
# #### Alertas de Input

# %%
navegador.find_element(By.XPATH, '/html/body/div[3]/button').click()

alerta = navegador.switch_to.alert
time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 navegador.find_element(By.XPATH, '/html/body/div[3]/button').click()
#       3 alerta = navegador.switch_to.alert
#       4 time.sleep(2)
#
# File c:\Users\Danih\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\Danih\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\Danih\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=141.0.7390.108); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0x4dfe83+66515]
# 	GetHandleVerifier [0x0x4dfec4+66580]
# 	(No symbol) [0x0x2cdc48]
# 	(No symbol) [0x0x2bce80]
# 	(No symbol) [0x0x2db81b]
# 	(No symbol) [0x0x341c25]
# 	(No symbol) [0x0x35c4d9]
# 	(No symbol) [0x0x33afc6]
# 	(No symbol) [0x0x30c2ca]
# 	(No symbol) [0x0x30d154]
# 	GetHandleVerifier [0x0x7373b3+2521347]
# 	GetHandleVerifier [0x0x732333+2500739]
# 	GetHandleVerifier [0x0x507cd4+229924]
# 	GetHandleVerifier [0x0x4f8238+165768]
# 	GetHandleVerifier [0x0x4feced+193085]
# 	GetHandleVerifier [0x0x4e8198+100072]
# 	GetHandleVerifier [0x0x4e8330+100480]
# 	GetHandleVerifier [0x0x4d25ea+11066]
# 	BaseThreadInitThunk [0x0x76fafcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x770f82ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x770f827e+238]

# %%
alerta.send_keys('123123') # lembre que ele funciona, apesar de não aparecer
alerta.accept()

# %%
# alerta.accept()
