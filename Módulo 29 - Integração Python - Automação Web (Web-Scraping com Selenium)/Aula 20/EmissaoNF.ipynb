# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions()
options.add_experimental_option("prefs", {
    "downloads.default_directory": r"C:\Users\Danih\OneDrive\Documentos\Python Impressionador\codigos\Módulo 29 - Integração Python - Automação Web (Web-Scraping com Selenium)\Aula 20",
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
}) #script pronto para aceitar automaticamente a opção de permitir download

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico, options=options) #incluimos a opção aqui no nosso navegador

# %%
#entrar na pagina de login
import os

caminho = os.getcwd()
arquivo = caminho + r"\login.html"
navegador.get(arquivo)

#preencher login e senha
login = navegador.find_element(By.XPATH, '/html/body/div/form/input[1]').send_keys("Daniel Coutinho")

senha = navegador.find_element(By.XPATH, '/html/body/div/form/input[2]').send_keys("123456")

#clicar em login
botao = navegador.find_element(By.XPATH, '/html/body/div/form/button').click()

#preencher os dados da nota fiscal
nome_razaosocial = navegador.find_element(By.NAME, 'nome').send_keys("Daniel LTDA")

endereco = navegador.find_element(By.NAME, 'endereco').send_keys("Rua serra de itabaiana")

bairro = navegador.find_element(By.NAME, 'bairro').send_keys("madala")

municipio = navegador.find_element(By.NAME, 'municipio').send_keys("SP")

cep = navegador.find_element(By.NAME, 'cep').send_keys("00000000")

uf = navegador.find_element(By.NAME, 'uf').send_keys("SP")

cnpj = navegador.find_element(By.NAME, 'cnpj').send_keys("099253872538")

inscricao = navegador.find_element(By.NAME, 'inscricao').send_keys("1533001")

descricao = navegador.find_element(By.NAME, 'descricao').send_keys("servico de tecnologia")

quantidade = navegador.find_element(By.NAME, 'quantidade').send_keys("3")

valor_unitario = navegador.find_element(By.NAME, 'valor_unitario').send_keys("250")

valor_total = navegador.find_element(By.NAME, 'total').send_keys("750")

#clicar em emitir nf

botaoemitir = navegador.find_element(By.XPATH, '//*[@id="formulario"]/button').click()
