# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print('Alo mundo')
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = input('Digite um numero')
print('O numero informado foi ' + numero )
# Out:
# O numero informado foi 10

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero1 = int(input('digite um numero'))
numero2 = int(input('digite outro numero'))

soma = numero1 + numero2

print(soma)
# Out:
# 5

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota1 = int(input('Qual a nota no 1bimestre'))
nota2 = int(input('Qual a nota no 2bimestre'))
nota3 = int(input('Qual a nota no 3bimestre'))
nota4 = int(input('Qual a nota no 4bimestre'))
media = (nota1 + nota2 + nota3 + nota4) / 4

print(media)
# Out:
# 8.5

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = float(input('informe o comprimento em metros'))
centimetros = metros * 100

print( f'O comprimento em centimetros é de: {centimetros} cm' )
# Out:
# O comprimento em centimetros é de: 1500.0 cm

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = float(input('qual largura da sala')) #7
comprimento = float(input('qual comprimento da sala')) #8
area = largura * comprimento

print(area)
# Out:
# 56.0

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganhohr = float(input('ganho por hora:'))
hr_trabalhada = float(input('horas trabalhadas no mes'))

salario = ganhohr * hr_trabalhada

print(f'o salario no mes é de {salario}')
# Out:
# o salario no mes é de 1779.8

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
fahrenheit = float(input('Qual temperatura em fahrenheit?'))
celsius = (fahrenheit - 32) / 1.8

print(f'{fahrenheit} graus em F equivale a {celsius} graus celsius')
# Out:
# 45.0 graus em F equivale a 7.222222222222222 graus celsius

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
celsius = float(input('Qual temperatura em grau celsius'))
fahrenheit = celsius * 1.8 + 32

print(f'{celsius} graus em C equivale a {fahrenheit} graus fahrenheit')
# Out:
# 45.0 graus em C equivale a 113.0 graus fahrenheit

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input('Qual sua altura?'))
peso_ideal = 72.7 * altura - 58

print(f'O peso ideal para quem mede {altura} é de {peso_ideal} kg')
# Out:
# O peso ideal para quem mede 1.8 é de 72.86000000000001 kg

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura = float(input('Informe a altura em metros'))
peso_ideal_homens = 72.7 * altura - 58
peso_ideal_mulheres = 62.1 * altura - 44.7

print(f'o peso ideal de mulher é: {peso_ideal_mulheres} kg')
print(f'o peso ideal de mulher é: {peso_ideal_homens} kg')
# Out:
# o peso ideal de mulher é: 61.491 kg
# o peso ideal de mulher é: 66.31700000000001 kg

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
ganhohr = float(input('quanto ganha por hora:'))
hr_trabalhada = float(input('quantas horas trabalhadas no mes'))

print(f'o ganhor por hora é de {ganhohr}. E as horas trabalhadas no mes são {hr_trabalhada}')
# Out:
# o ganhor por hora é de 8.09. E as horas trabalhadas no mes são 220.0

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
horas = 220
salario_hr = 8.09
salario_bruto = horas * salario_hr

print(salario_bruto)
# Out:
# 1779.8

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
ir = 0.11 * salario_bruto

print(ir)
# Out:
# 195.778

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
inss = 0.08 * salario_bruto
print(inss)
# Out:
# 142.384

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
sind = 0.05 * salario_bruto
print(sind)
# Out:
# 88.99000000000001

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
liquido = salario_bruto - ir - inss - sind

print(liquido)
# Out:
# 1352.648

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area_m2 = float(input('Qual tamanho da area em metros quadrados?'))
tinta_litro = area_m2 / 3

latas = tinta_litro / 18
preco = latas * 80

print(f'Serão necessárias {latas} latas, custando R$ {preco} no total')
# Out:
# Serão necessárias 1.0 latas, custando R$ 80.0 no total

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
arquivo = float(input('qual tamanho do arquivo em MB'))
link = float(input('qual velocidade de um link de internet'))

tamanho_megabits = arquivo * 8

tempo = tamanho_megabits / link
tempo_minutos = tempo / 60


print(f'O tempo é de aproximadamente {tempo_minutos} minutos')
# Out:
# O tempo é de aproximadamente 2.533333333333333 minutos
